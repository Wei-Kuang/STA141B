# %% [markdown]
# # STA 141B: Homework 4
# ## Wei-Kuang  (Jerry) Lin

# %% [markdown]
# ## Requesting freshness
#
# In this portion, you'll combine the assignment 3 data set with nutrition data from the [USDA Food Composition Databases](https://ndb.nal.usda.gov/ndb/search/list). The CSV file `fresh.csv` contains the fresh fruits and vegetables data you extracted in assignment 3.
#
# The USDA Food Composition Databases have a [documented](https://ndb.nal.usda.gov/ndb/doc/index) web API that returns data in JSON format . You need a key in order to use the API. Only 1000 requests are allowed per hour, so it would be a good idea to use [caching][requests_cache].
#
# [Sign up for an API key here](https://api.data.gov/signup/). The key will work with any Data.gov API. You may need the key again later in the quarter, so make sure you save it.
#
# These modules may be useful:
#
# * [requests](http://docs.python-requests.org/en/master/user/quickstart/)
# * [requests_cache][]
# * [urlparse](https://docs.python.org/2/library/urlparse.html)
# * [pandas](http://pandas.pydata.org/pandas-docs/stable/)
#
# [requests_cache]: https://pypi.python.org/pypi/requests-cache

# %% [markdown]
# __Exercise 1.1__ (20 pts)
#
# Read the [search request documentation](https://ndb.nal.usda.gov/ndb/doc/apilist/API-SEARCH.md), then write a function called `ndb_search()` that makes a search request. The function should accept the search term as an argument. The function should return the search result items as a list (for 0 items, return an empty list).
#
# Note that the search url is: `https://api.nal.usda.gov/ndb/search`
#
# As an example, a search for `"quail eggs"` should return this list:
#
# ```python
# [{u'ds': u'BL',
#   u'group': u'Branded Food Products Database',
#   u'name': u'CHAOKOH, QUAIL EGG IN BRINE, UPC: 044738074186',
#   u'ndbno': u'45094707',
#   u'offset': 0},
#  {u'ds': u'BL',
#   u'group': u'Branded Food Products Database',
#   u'name': u'L&W, QUAIL EGGS, UPC: 024072000256',
#   u'ndbno': u'45094890',
#   u'offset': 1},
#  {u'ds': u'BL',
#   u'group': u'Branded Food Products Database',
#   u'name': u'BUDDHA, QUAIL EGGS IN BRINE, UPC: 761934535098',
#   u'ndbno': u'45099560',
#   u'offset': 2},
#  {u'ds': u'BL',
#   u'group': u'Branded Food Products Database',
#   u'name': u'GRAN SABANA, QUAIL EGGS, UPC: 819140010103',
#   u'ndbno': u'45169279',
#   u'offset': 3},
#  {u'ds': u'BL',
#   u'group': u'Branded Food Products Database',
#   u'name': u"D'ARTAGNAN, QUAIL EGGS, UPC: 736622102630",
#   u'ndbno': u'45178254',
#   u'offset': 4},
#  {u'ds': u'SR',
#   u'group': u'Dairy and Egg Products',
#   u'name': u'Egg, quail, whole, fresh, raw',
#   u'ndbno': u'01140',
#   u'offset': 5}]
# ```
#
# As usual, make sure you document and test your function.

# %% [markdown]
# __Action to Exercise 1.1__

# %%
# Basic library
import numpy as np
import pandas as pd

# %%
# Set up a cache for requests
import requests_cache
requests_cache.install_cache('demo_cache')

# %% [markdown]
# #### Understand how to use "NDB API" web API that returns data in JSON format
#
# * https://ndb.nal.usda.gov/ndb/doc/apilist/API-SEARCH.md
#
# | Name    | Required | Default | Description                                                                   |
# |---------|----------|---------|-------------------------------------------------------------------------------|
# | api_key | y        | n/a     | Must be a data.gov registered API key                                         |
# | q       | n        | ""      | Search terms                                                                  |
# | ds      | n        | ""      | Data source. Must be either 'Branded Food   Products' or 'Standard Reference' |
# | fg      | n        | ""      | Food group ID                                                                 |
# | sort    | n        | r       | Sort the results by food name (n) or by   search relevance (r)                |
# | max     | n        | 50      | maximum rows to return                                                        |
# | offset  | n        | 0       | beginning row in the result set to begin                                      |
# | format1 | n        | JSON    | results format: json or xml                                                   |

# %% [markdown]
# ####  Making HTTP Requests With Python using "requests" library
# * useful reading: https://realpython.com/python-requests/
# * Backgroud information of HTTP Request Methods: https://www.w3schools.com/tags/ref_httpmethods.asp

# %%
import requests

# I already registered to get a key to access USDA Food Composition Databases
API_Key = "mnRoh2yEr1dhWf9NiBF4Z9KQOGnlu7yHajt78hZc"
url = "https://api.nal.usda.gov/ndb/search"
response= requests.get(url,                             # "get" method of request to have your request results from 'url'
                       params = {"api_key":API_Key} )   # Save it as "response"
response.status_code                                    # "status_code" == 200 indicate that the request is successful.
# Out:
# 200

# %% [markdown]
# __Function ndb_search( ) construnction for Exercise 1.1__

# %%
def ndb_search(term):
    '''
    Action: A function called ndb_search() that makes a search request based on the term (user input)
    Arguemnt: this function accept the search term as an argument
    Return: it returns the search result items as a list (for 0 items, return an empty list)
    '''
    # Set up my key to access the database
    API_Key = "mnRoh2yEr1dhWf9NiBF4Z9KQOGnlu7yHajt78hZc"
    
    response = requests.get( 
        "https://api.nal.usda.gov/ndb/search", 
        params = {"api_key": API_Key, "q": term, "format": "json"}
    )

    if (term == 0 or term == None or term ==[]):
        response = [None]
        print("No request is provided")
    
    elif response.json().keys()  == {'errors'}:
        response = [None]
        print("Zero results can be found for the requested term")
    
    else:
        return response.json()['list']['item']

# %%
# Fuction test: it's correct 
test = ndb_search("XXOXX")
test is None
# Out:
# Zero results can be found for the requested term
# True

# %%
# Fuction test: it's correct 
ndb_search("quail eggs")
# Out:
# [{'ds': 'BL',
#   'group': 'Branded Food Products Database',
#   'name': 'GRAN SABANA, QUAIL EGGS, UPC: 819140010103',
#   'ndbno': '45169279',
#   'offset': 0},
#  {'ds': 'BL',
#   'group': 'Branded Food Products Database',
#   'name': "D'ARTAGNAN, QUAIL EGGS, UPC: 736622102630",
#   'ndbno': '45178254',
#   'offset': 1},
#  {'ds': 'BL',
#   'group': 'Branded Food Products Database',
#   'name': 'CHAOKOH, QUAIL EGG IN BRINE, UPC: 044738074186',
#   'ndbno': '45094707',
#   'offset': 2},
#  {'ds': 'BL',
#   'group': 'Branded Food Products Database',
#   'name': 'L&W, QUAIL EGGS, UPC: 024072000256',
#   'ndbno': '45094890',
#   'offset': 3},
#  {'ds': 'BL',
#   'group': 'Branded Food Products Database',
#   'name': 'BUDDHA, QUAIL EGGS IN BRINE, UPC: 761934535098',
#   'ndbno': '45099560',
#   'offset': 4},
#  {'ds': 'SR',
#   'group': 'Dairy and Egg Products',
#   'name': 'Egg, quail, whole, fresh, raw',
#   'ndbno': '01140',
#   'offset': 5}]

# %% [markdown]
# __Exercise 1.2__ (20 pts)
#
# Use your search function to get NDB numbers for the foods in the `fresh.csv` file. It's okay if you don't get an NDB number for every food, but try to come up with a strategy that gets most of them. Discuss your strategy in a short paragraph.

# %%
#### Check the data frame content of search result
dframe = pd.read_csv('fresh.csv')                                # Read fresh.csv file
selection = list(range(0,3)) + list(range(46,len(dframe))  )     # Show the head and tail of the dataframe
dframe.iloc[selection, :]
# Out:
#       form  price_per_lb  yield  lb_per_cup  price_per_cup              food  \
# 0   Fresh1      0.333412   0.52    0.330693       0.212033        watermelon
# 1   Fresh1      0.535874   0.51    0.374786       0.393800        cantaloupe
# 2   Fresh1      1.377962   0.74    0.407855       0.759471        tangerines
# 46  Fresh1      1.410363   0.82    0.264555       0.455022     green_peppers
# 47  Fresh1      2.763553   1.06    0.341717       0.890898  brussels_sprouts
# 48  Fresh1      2.690623   0.54    0.363763       1.812497        corn_sweet
#
#           type
# 0        fruit
# 1        fruit
# 2        fruit
# 46  vegetables
# 47  vegetables
# 48  vegetables

# %%
#### Check the request results in dataframe
pd.DataFrame(ndb_search("quail eggs"))
# Out:
#    ds                           group  \
# 0  BL  Branded Food Products Database
# 1  BL  Branded Food Products Database
# 2  BL  Branded Food Products Database
# 3  BL  Branded Food Products Database
# 4  BL  Branded Food Products Database
# 5  SR          Dairy and Egg Products
#
#                                              name     ndbno  offset
# 0      GRAN SABANA, QUAIL EGGS, UPC: 819140010103  45169279       0
# 1       D'ARTAGNAN, QUAIL EGGS, UPC: 736622102630  45178254       1
# 2  CHAOKOH, QUAIL EGG IN BRINE, UPC: 044738074186  45094707       2
# 3              L&W, QUAIL EGGS, UPC: 024072000256  45094890       3
# 4  BUDDHA, QUAIL EGGS IN BRINE, UPC: 761934535098  45099560       4
# 5                   Egg, quail, whole, fresh, raw     01140       5

# %% [markdown]
# #### Planned actions :
# 1. My strategy is to extract the "food" column from fresh.csv file.
# 2. Create a for loop based to iterate through the food column and each food name is the input for ndb_search() function.
# 3. ndb_search() will serach the ndb number through search url https://api.nal.usda.gov/ndb/search.
# 4. To avoid the unacceptable string structure (ex " _ " in the food name), I use str.replace() to replace " - " with emptyspace.
# 5. To select the food which are raw and unbranded, I use string method to select "SR" from the ds column and then select raw in the "name column".
# 6. I need a empty data frame with six columns to stored the searched information.

# %% [markdown]
# #### Execution

# %%
# Read the food name in the csv file
path= ("C:/Users/WeiKuang/Documents/GitHub/141b-hw4-Wei-Kuang/fresh.csv")
fresh_df = pd.read_csv(path)

# Form better terms used for search
corrected_name = [x.replace("_"," ") for x in fresh_df['food'] ]
form           = [x.replace("Fresh1","") for x in fresh_df['form'] ]
form           = [x.replace("Fresh","") for x in form ]
form           = [x.replace("1","") for x in form ]
form           = [x.replace(",","") for x in form ]
form           = [x.replace("consumed with","") for x in form ]

new_var = []
for i in range(fresh_df.shape[0]) :
    x = corrected_name[i] + " " + form[i]
    new_var = new_var + [x]

fresh_df['term'] = new_var
fresh_df
# Out:
#                           form  price_per_lb     yield  lb_per_cup  \
# 0                       Fresh1      0.333412  0.520000    0.330693
# 1                       Fresh1      0.535874  0.510000    0.374786
# 2                       Fresh1      1.377962  0.740000    0.407855
# 3                       Fresh1      2.358808  0.940000    0.319670
# 4                       Fresh1      1.827416  0.940000    0.363763
# 5                       Fresh1      1.035173  0.730000    0.407855
# 6                       Fresh1      6.975811  0.960000    0.319670
# 7                       Fresh1      2.173590  0.560000    0.341717
# 8                       Fresh1      0.627662  0.510000    0.363763
# 9                       Fresh1      3.040072  0.930000    0.363763
# 10                      Fresh1      0.796656  0.460000    0.374786
# 11                      Fresh1      1.298012  0.620000    0.308647
# 12                      Fresh1      2.044683  0.760000    0.385809
# 13                      Fresh1      3.592990  0.920000    0.341717
# 14                      Fresh1      0.566983  0.640000    0.330693
# 15                      Fresh1      1.567515  0.900000    0.242508
# 16                      Fresh1      1.591187  0.960000    0.341717
# 17                      Fresh1      1.761148  0.910000    0.319670
# 18                      Fresh1      1.461575  0.900000    0.363763
# 19                      Fresh1      0.897802  0.490000    0.462971
# 20                     Fresh1       5.774708  0.960000    0.319670
# 21                      Fresh1      2.093827  0.960000    0.330693
# 22                      Fresh1      4.734622  0.950000    0.319670
# 23                      Fresh1      1.377563  0.710000    0.363763
# 24                      Fresh1      3.213494  0.493835    0.396832
# 25  Fresh, consumed with peel1      1.295931  0.970000    0.264555
# 26              Fresh, peeled1      1.295931  0.730000    0.264555
# 27                      Fresh1      1.213039  0.950000    0.242508
# 28                      Fresh1      1.038107  0.900000    0.352740
# 29                      Fresh1      2.471749  0.750000    0.319670
# 30                      Fresh1      2.569235  0.840000    0.308647
# 31                      Fresh1      0.564320  0.811301    0.264555
# 32                      Fresh1      2.630838  1.160000    0.286601
# 33                      Fresh1      2.139972  0.846575    0.275578
# 34                      Fresh1      1.172248  0.458554    0.451948
# 35                      Fresh1      2.277940  0.820000    0.264555
# 36        Fresh green cabbage1      0.579208  0.778797    0.330693
# 37          Fresh red cabbage1      1.056450  0.779107    0.330693
# 38                      Fresh1      0.918897  0.811301    0.440925
# 39                      Fresh1      1.639477  0.769500    0.396832
# 40                      Fresh1      1.311629  0.900000    0.275578
# 41                      Fresh1      1.244737  0.714000    0.451948
# 42                      Fresh1      2.235874  0.740753    0.319670
# 43                      Fresh1      2.807302  1.050000    0.286601
# 44                      Fresh1      2.213050  0.375309    0.385809
# 45                      Fresh1      3.213552  0.769474    0.352740
# 46                      Fresh1      1.410363  0.820000    0.264555
# 47                      Fresh1      2.763553  1.060000    0.341717
# 48                      Fresh1      2.690623  0.540000    0.363763
#
#     price_per_cup              food        type                    term
# 0        0.212033        watermelon       fruit             watermelon
# 1        0.393800        cantaloupe       fruit             cantaloupe
# 2        0.759471        tangerines       fruit             tangerines
# 3        0.802171      strawberries       fruit           strawberries
# 4        0.707176             plums       fruit                  plums
# 5        0.578357           oranges       fruit                oranges
# 6        2.322874       raspberries       fruit            raspberries
# 7        1.326342       pomegranate       fruit            pomegranate
# 8        0.447686         pineapple       fruit              pineapple
# 9        1.189102          apricots       fruit               apricots
# 10       0.649077          honeydew       fruit               honeydew
# 11       0.646174            papaya       fruit                 papaya
# 12       1.037970              kiwi       fruit                   kiwi
# 13       1.334548          cherries       fruit               cherries
# 14       0.292965           bananas       fruit                bananas
# 15       0.422373            apples       fruit                 apples
# 16       0.566390           peaches       fruit                peaches
# 17       0.618667        nectarines       fruit             nectarines
# 18       0.590740             pears       fruit                  pears
# 19       0.848278        grapefruit       fruit             grapefruit
# 20       1.922919      blackberries       fruit          blackberries
# 21       0.721266            grapes       fruit                 grapes
# 22       1.593177       blueberries       fruit            blueberries
# 23       0.705783           mangoes       fruit                mangoes
# 24       2.582272         asparagus  vegetables              asparagus
# 25       0.353448         cucumbers  vegetables        cucumbers   peel
# 26       0.469650         cucumbers  vegetables       cucumbers  peeled
# 27       0.309655   lettuce_iceberg  vegetables        lettuce iceberg
# 28       0.406868            onions  vegetables                 onions
# 29       1.053526     turnip_greens  vegetables          turnip greens
# 30       0.944032    mustard_greens  vegetables         mustard greens
# 31       0.184017          potatoes  vegetables               potatoes
# 32       0.650001    collard_greens  vegetables         collard greens
# 33       0.696606       green_beans  vegetables            green beans
# 34       1.155360      acorn_squash  vegetables           acorn squash
# 35       0.734926       red_peppers  vegetables            red peppers
# 36       0.245944           cabbage  vegetables  cabbage  green cabbage
# 37       0.448412           cabbage  vegetables    cabbage  red cabbage
# 38       0.499400    sweet_potatoes  vegetables         sweet potatoes
# 39       0.845480     summer_squash  vegetables          summer squash
# 40       0.401618            radish  vegetables                 radish
# 41       0.787893  butternut_squash  vegetables       butternut squash
# 42       0.964886          avocados  vegetables               avocados
# 43       0.766262              kale  vegetables                   kale
# 44       2.274967         artichoke  vegetables              artichoke
# 45       1.473146              okra  vegetables                   okra
# 46       0.455022     green_peppers  vegetables          green peppers
# 47       0.890898  brussels_sprouts  vegetables       brussels sprouts
# 48       1.812497        corn_sweet  vegetables             corn sweet

# %% [markdown]
# #### For loop

# %%
# Creat an empty dataframe to store results from iteration
DF_ndbno = pd.DataFrame(pd.np.empty((0, 6))) 
DF_ndbno.columns = ['term','ds','group','name', 'ndbno','offset']

for term_i in fresh_df['term']:
    df = ndb_search(term_i)
    
    if df is None:
        pass
    else:
        # convert into dataframe
        df = pd.DataFrame(df)

        # Select the row where "SR" is in the ds columns
        is_SR = df['ds'].str.contains("SR").fillna(False)
        df = df.loc[is_SR,:]

        # Select raw in name column
        is_RAW = df['name'].str.contains(", raw").fillna(False)
        df = df.loc[is_RAW,:]

        #insert the food name in "food column"
        df.insert(0,'term',term_i)

        # Append the data
        DF_ndbno = DF_ndbno.append(df)

# %%
print( "shape : ", DF_ndbno.shape)
DF_ndbno.head(10)
# Out:
# shape :  (132, 7)
#     ds                    group  manu                                 name  \
# 11  SR  Fruits and Fruit Juices  none                      Watermelon, raw
# 0   SR  Fruits and Fruit Juices  none              Melons, cantaloupe, raw
# 5   SR  Fruits and Fruit Juices  none  Tangerines, (mandarin oranges), raw
# 6   SR  Fruits and Fruit Juices  none                 Tangerine juice, raw
# 60  SR  Fruits and Fruit Juices  none                    Strawberries, raw
# 65  SR  Fruits and Fruit Juices  none              Guavas, strawberry, raw
# 3   SR  Fruits and Fruit Juices  none                           Plums, raw
# 4   SR  Fruits and Fruit Juices  none           Carissa, (natal-plum), raw
# 5   SR  Fruits and Fruit Juices  none           Java-plum, (jambolan), raw
# 90  SR  Fruits and Fruit Juices  none  Oranges, raw, California, valencias
#
#     ndbno  offset           term
# 11  09326    11.0    watermelon
# 0   09181     0.0    cantaloupe
# 5   09218     5.0    tangerines
# 6   09221     6.0    tangerines
# 60  09316    60.0  strawberries
# 65  09140    65.0  strawberries
# 3   09279     3.0         plums
# 4   09061     4.0         plums
# 5   09145     5.0         plums
# 90  09201    90.0       oranges

# %% [markdown]
# #### Remove the duplication of the food
# Reference: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop_duplicates.html

# %%
DF_ndbno_cleaned= DF_ndbno.copy()
# Remove the duplicated food
DF_ndbno_cleaned = DF_ndbno_cleaned.drop_duplicates(subset='term', keep='first')   # subset is the column name
# Remove the unwanted columns
DF_ndbno_cleaned = DF_ndbno_cleaned.drop(['group','manu','offset'], axis=1)               # axis=1 (coulumn-wise)
DF_ndbno_cleaned = DF_ndbno_cleaned.reset_index(drop = True)                       # Drop the original row index
print("shape :", DF_ndbno_cleaned.shape) 
DF_ndbno_cleaned.head(10)
# Out:
# shape : (44, 4)
#    ds                                 name  ndbno           term
# 0  SR                      Watermelon, raw  09326    watermelon
# 1  SR              Melons, cantaloupe, raw  09181    cantaloupe
# 2  SR  Tangerines, (mandarin oranges), raw  09218    tangerines
# 3  SR                    Strawberries, raw  09316  strawberries
# 4  SR                           Plums, raw  09279         plums
# 5  SR  Oranges, raw, California, valencias  09201       oranges
# 6  SR                     Raspberries, raw  09302   raspberries
# 7  SR                    Pomegranates, raw  09286   pomegranate
# 8  SR        Pineapple, raw, all varieties  09266     pineapple
# 9  SR                        Apricots, raw  09021      apricots

# %% [markdown]
# #### Merge the ndb number into the food csv file
# * The goal is to have ndb number and price information for a food
# reading: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html

# %%
DF_Merge = fresh_df.merge(DF_ndbno_cleaned, left_on='term', right_on='term', how='inner')
print("shape :", DF_Merge.shape) 
DF_Merge.head()
# Out:
# shape : (44, 11)
#      form  price_per_lb  yield  lb_per_cup  price_per_cup          food  \
# 0  Fresh1      0.333412   0.52    0.330693       0.212033    watermelon
# 1  Fresh1      0.535874   0.51    0.374786       0.393800    cantaloupe
# 2  Fresh1      1.377962   0.74    0.407855       0.759471    tangerines
# 3  Fresh1      2.358808   0.94    0.319670       0.802171  strawberries
# 4  Fresh1      1.827416   0.94    0.363763       0.707176         plums
#
#     type           term  ds                                 name  ndbno
# 0  fruit    watermelon   SR                      Watermelon, raw  09326
# 1  fruit    cantaloupe   SR              Melons, cantaloupe, raw  09181
# 2  fruit    tangerines   SR  Tangerines, (mandarin oranges), raw  09218
# 3  fruit  strawberries   SR                    Strawberries, raw  09316
# 4  fruit         plums   SR                           Plums, raw  09279

# %% [markdown]
# __Exercise 1.3__ (20 pts)
#
# Read the [food reports V2 documentation](https://ndb.nal.usda.gov/ndb/doc/apilist/API-FOOD-REPORTV2.md), then write a function called `ndb_report()` that requests a _basic_ food report. The function should accept the NDB number as an argument and return the list of nutrients for the food.
#
# | Parameter | Required | Default   | Description                                 |
# |-----------|----------|-----------|---------------------------------------------|
# | api_key   | y        | n/a       | Must be a   data.gov registered API key     |
# | ndbno     | y        | n/a       | A list of   up to 25 NDB numbers            |
# | type      | n        | b (basic) | Report   type: [b]asic or [f]ull or [s]tats |
# | format1   | n        | JSON      | Report   format: xml or json                |
#
# Note that the report url is: `https://api.nal.usda.gov/ndb/V2/reports`
#
# For example, for `"09279"` (raw plums) the first element of the returned list should be:
#
# ```python
# {u'group': u'Proximates',
#  u'measures': [{u'eqv': 165.0,
#    u'eunit': u'g',
#    u'label': u'cup, sliced',
#    u'qty': 1.0,
#    u'value': u'143.93'},
#   {u'eqv': 66.0,
#    u'eunit': u'g',
#    u'label': u'fruit (2-1/8" dia)',
#    u'qty': 1.0,
#    u'value': u'57.57'},
#   {u'eqv': 151.0,
#    u'eunit': u'g',
#    u'label': u'NLEA serving',
#    u'qty': 1.0,
#    u'value': u'131.72'}],
#  u'name': u'Water',
#  u'nutrient_id': u'255',
#  u'unit': u'g',
#  u'value': u'87.23'}
# ```
#
# Be sure to document and test your function.

# %% [markdown]
# #### My action to Exercise 1.3

# %%
# Analyze the structure using ".keys()" method for dictionary
NDB ='09279'
response = requests.get( "https://api.nal.usda.gov/ndb/V2/reports", 
                                params = {
                                    "api_key": "mnRoh2yEr1dhWf9NiBF4Z9KQOGnlu7yHajt78hZc",
                                    "ndbno": NDB,
                                    "type": "b",
                                    "format": "json"})
response
# Out:
# <Response [200]>

# %%
print( type(  response.json()['foods'][0]['food']['nutrients']    ) )  # nutrients is a list 
print(  len(  response.json()['foods'][0]['food']['nutrients']    ) )  # It has 33 elements
print(        response.json()['foods'][0]['food']['nutrients'][0:3] )  # Show the first 3 items

df = pd.DataFrame( response.json()['foods'][0]['food']['nutrients'] )
df.head(5)
# Out:
# <class 'list'>
# 33
# [{'nutrient_id': '255', 'name': 'Water', 'derivation': 'NONE', 'group': 'Proximates', 'unit': 'g', 'value': '87.23', 'measures': [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit': 'g', 'qty': 1.0, 'value': '143.93'}, {'label': 'fruit (2-1/8" dia)', 'eqv': 66.0, 'eunit': 'g', 'qty': 1.0, 'value': '57.57'}, {'label': 'NLEA serving', 'eqv': 151.0, 'eunit': 'g', 'qty': 1.0, 'value': '131.72'}]}, {'nutrient_id': '208', 'name': 'Energy', 'derivation': 'NC', 'group': 'Proximates', 'unit': 'kcal', 'value': '46', 'measures': [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit': 'g', 'qty': 1.0, 'value': '76'}, {'label': 'fruit (2-1/8" dia)', 'eqv': 66.0, 'eunit': 'g', 'qty': 1.0, 'value': '30'}, {'label': 'NLEA serving', 'eqv': 151.0, 'eunit': 'g', 'qty': 1.0, 'value': '69'}]}, {'nutrient_id': '203', 'name': 'Protein', 'derivation': 'NONE', 'group': 'Proximates', 'unit': 'g', 'value': '0.70', 'measures': [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit': 'g', 'qty': 1.0, 'value': '1.15'}, {'label': 'fruit (2-1/8" dia)', 'eqv': 66.0, 'eunit': 'g', 'qty': 1.0, 'value': '0.46'}, {'label': 'NLEA serving', 'eqv': 151.0, 'eunit': 'g', 'qty': 1.0, 'value': '1.06'}]}]
#   derivation       group                                           measures  \
# 0       NONE  Proximates  [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit...
# 1         NC  Proximates  [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit...
# 2       NONE  Proximates  [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit...
# 3       NONE  Proximates  [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit...
# 4         NC  Proximates  [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit...
#
#                           name nutrient_id  unit  value
# 0                        Water         255     g  87.23
# 1                       Energy         208  kcal     46
# 2                      Protein         203     g   0.70
# 3            Total lipid (fat)         204     g   0.28
# 4  Carbohydrate, by difference         205     g  11.42

# %% [markdown]
# __My Note: __
# 1. There are 33 items in the 'nutrients' list
# 2. Let's convert it into a dataframe to have a better ideas about the output!
# 3. Now, I know that output['foods'][0]['food']['nutrients'] provides all kinds of nutrients information.
# 4. Then, I can select certains rwos to report ( i.g., Energy, Protein, Fiber, etc. ).

# %% [markdown]
# #### Set up the rows that I am interested in.

# %%
My_interest = ['Energy', 
               'Fiber, total dietary', 
               'Calcium, Ca', 
               'Iron, Fe', 
               'Magnesium, Mg', 
               'Vitamin C, total ascorbic acid',
               'Vitamin B-6',
               'Vitamin B-12',
               'Vitamin E (alpha-tocopherol)']


logic_selection= [x in My_interest for x in df['name'] ]
df.loc[logic_selection]
# Out:
#    derivation       group                                           measures  \
# 1          NC  Proximates  [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit...
# 5        NONE  Proximates  [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit...
# 7        NONE    Minerals  [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit...
# 8        NONE    Minerals  [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit...
# 9        NONE    Minerals  [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit...
# 14       NONE    Vitamins  [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit...
# 18       NONE    Vitamins  [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit...
# 20       NONE    Vitamins  [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit...
# 23       NONE    Vitamins  [{'label': 'cup, sliced', 'eqv': 165.0, 'eunit...
#
#                               name nutrient_id  unit  value
# 1                           Energy         208  kcal     46
# 5             Fiber, total dietary         291     g    1.4
# 7                      Calcium, Ca         301    mg      6
# 8                         Iron, Fe         303    mg   0.17
# 9                    Magnesium, Mg         304    mg      7
# 14  Vitamin C, total ascorbic acid         401    mg    9.5
# 18                     Vitamin B-6         415    mg  0.029
# 20                    Vitamin B-12         418    µg   0.00
# 23    Vitamin E (alpha-tocopherol)         323    mg   0.26

# %% [markdown]
# #### Write a function "food_report" to extract the food nutrition

# %%
def food_report(NDB):
    '''
    Action: A function that makes a search request based on the NDB number
    Arguemnt: this function accept "NDB" number as an argument
    Return: it returns the list of nutrients for the food.
    '''
    if NDB == 0 :
        response = []
        return response
    
    elif NDB == None:
        response = []
        return response
    
    else:
        response = requests.get( "https://api.nal.usda.gov/ndb/V2/reports", 
                                params = {
                                    "api_key": "mnRoh2yEr1dhWf9NiBF4Z9KQOGnlu7yHajt78hZc",
                                    "ndbno": NDB,
                                    "type": "b",
                                    "format": "json"})
        
        return response.json()['foods'][0]['food']['nutrients']

# Note: use type() to test whether the returned object is a dict or list

# %%
# Test: the first element of the returned list, with NDB = "09279" (raw plums) 
pd.DataFrame(food_report("09279")[0] )
# Out:
#   derivation       group                                           measures  \
# 0       NONE  Proximates  {'label': 'cup, sliced', 'eqv': 165.0, 'eunit'...
# 1       NONE  Proximates  {'label': 'fruit (2-1/8" dia)', 'eqv': 66.0, '...
# 2       NONE  Proximates  {'label': 'NLEA serving', 'eqv': 151.0, 'eunit...
#
#     name nutrient_id unit  value
# 0  Water         255    g  87.23
# 1  Water         255    g  87.23
# 2  Water         255    g  87.23

# %% [markdown]
# __Exercise 1.4__ (20 pts) Which foods provide the best combination of price, yield, and nutrition? You can use kilocalories as a measure of "nutrition" here, but more a detailed analysis is better. Use plots to support your analysis.

# %% [markdown]
# #### Step 1: Form a temporary dataframe that has ndb number and nutrients of my interest

# %%
My_interest = ['Energy', 
               'Fiber, total dietary', 
               'Calcium, Ca', 
               'Iron, Fe', 
               'Magnesium, Mg', 
               'Vitamin C, total ascorbic acid',
               'Vitamin B-6',
               'Vitamin B-12',
               'Vitamin E (alpha-tocopherol)']

# %%
# Creat an empty dataframe for "for loop"
DF_ndb_nutri = pd.DataFrame(pd.np.empty((0, 10)))   # create a empty dataframe with 5 cols
DF_ndb_nutri.columns = ['ndbno'] + My_interest      # correct the column names
DF_ndb_nutri
# Out:
# Empty DataFrame
# Columns: [ndbno, Energy, Fiber, total dietary, Calcium, Ca, Iron, Fe, Magnesium, Mg, Vitamin C, total ascorbic acid, Vitamin B-6, Vitamin B-12, Vitamin E (alpha-tocopherol)]
# Index: []

# %% [markdown]
# #### Step 2: Execution:

# %%
for NDB in DF_Merge['ndbno']:
    
    # convert the list to dataframe
    df1 = pd.DataFrame( food_report( NDB ) )
    
    # If the list of nutrient is not complete, then skip this one and move to the next food 
    if len(df1.iloc[:,0]) !=33:
        next
    
    else:
        # Drop the uesless columns
        df1 = df1.drop(['group','derivation', 'measures'], axis=1)
        
        # Select nutrients of my interest
        logic_selection= [x in My_interest for x in df['name'] ]
        df1= df1.loc[logic_selection]
        
        # transpose
        df1_T = df1.transpose()
        # n_df_s_T.columns = [list(n_df_s_T.iloc[0])] # rename the col
        df1_T.columns = My_interest
        
        # select the row of value
        df1_T = df1_T.iloc[[3]]
        
        # Add the ndb number
        df1_T.insert(0,"ndbno", NDB)
        
        # Append
        DF_ndb_nutri = DF_ndb_nutri.append(df1_T)

# %%
# Modify column names
DF_ndb_nutri.columns =  [
               'ndbno',
               'Energy', 
               'Fiber', 
               'Calcium', 
               'Iron', 
               'Magnesium', 
               'Vitamin C',
               'Vitamin B-6',
               'Vitamin B-12',
               'Vitamin E']

DF_ndb_nutri.head()
# Out:
#        ndbno Energy Fiber Calcium  Iron Magnesium Vitamin C Vitamin B-6  \
# value  09326     30   0.4       7  0.24        10       8.1       0.045
# value  09181     34   0.9       9  0.21        12      36.7       0.072
# value  09218     53   1.8      37  0.15        12      26.7       0.078
# value  09316     32   2.0      16  0.41        13      58.8       0.047
# value  09279     46   1.4       6  0.17         7       9.5       0.029
#
#       Vitamin B-12 Vitamin E
# value         0.00      0.05
# value         0.00      0.05
# value         0.00      0.20
# value         0.00      0.29
# value         0.00      0.26

# %%
# Merge 
DF_final = DF_Merge.merge(DF_ndb_nutri, left_on='ndbno', right_on='ndbno', how='inner')
print("shape: ", DF_final.shape)
DF_final.head(3)
# Out:
# shape:  (39, 20)
#      form  price_per_lb  yield  lb_per_cup  price_per_cup        food   type  \
# 0  Fresh1      0.333412   0.52    0.330693       0.212033  watermelon  fruit
# 1  Fresh1      0.535874   0.51    0.374786       0.393800  cantaloupe  fruit
# 2  Fresh1      1.377962   0.74    0.407855       0.759471  tangerines  fruit
#
#           term  ds                                 name  ndbno Energy Fiber  \
# 0  watermelon   SR                      Watermelon, raw  09326     30   0.4
# 1  cantaloupe   SR              Melons, cantaloupe, raw  09181     34   0.9
# 2  tangerines   SR  Tangerines, (mandarin oranges), raw  09218     53   1.8
#
#   Calcium  Iron Magnesium Vitamin C Vitamin B-6 Vitamin B-12 Vitamin E
# 0       7  0.24        10       8.1       0.045         0.00      0.05
# 1       9  0.21        12      36.7       0.072         0.00      0.05
# 2      37  0.15        12      26.7       0.078         0.00      0.20

# %%
# Drop columns that are not used for the analysis
DF_final= DF_final.drop(['form','lb_per_cup', 'price_per_cup', 'type', 'ds', 'food', 'name'], axis=1)
DF_final.head()
# Out:
#    price_per_lb  yield           term  ndbno Energy Fiber Calcium  Iron  \
# 0      0.333412   0.52    watermelon   09326     30   0.4       7  0.24
# 1      0.535874   0.51    cantaloupe   09181     34   0.9       9  0.21
# 2      1.377962   0.74    tangerines   09218     53   1.8      37  0.15
# 3      2.358808   0.94  strawberries   09316     32   2.0      16  0.41
# 4      1.827416   0.94         plums   09279     46   1.4       6  0.17
#
#   Magnesium Vitamin C Vitamin B-6 Vitamin B-12 Vitamin E
# 0        10       8.1       0.045         0.00      0.05
# 1        12      36.7       0.072         0.00      0.05
# 2        12      26.7       0.078         0.00      0.20
# 3        13      58.8       0.047         0.00      0.29
# 4         7       9.5       0.029         0.00      0.26

# %% [markdown]
# #### Step 3: Analysis
# The best value is what we could spend the one dollar to gain the most weight from the edible part of food. I create a colunm called "edible_pound per_1_dollar" to reflect this idea. The formula of "edible_pound_per_1_dollar" is [ yield /  price per pound ], and the larger value, the better.

# %%
edible_pound_per_1_dollar = DF_final['yield'] / DF_final['price_per_lb']

# %%
DF_final.insert(2, "edible_pount_per_1_dollar",edible_pound_per_1_dollar)

# %%
DF_final.head()
# Out:
#    price_per_lb  yield  edible_pount_per_1_dollar           term  ndbno  \
# 0      0.333412   0.52                   1.559632    watermelon   09326
# 1      0.535874   0.51                   0.951717    cantaloupe   09181
# 2      1.377962   0.74                   0.537025    tangerines   09218
# 3      2.358808   0.94                   0.398506  strawberries   09316
# 4      1.827416   0.94                   0.514388         plums   09279
#
#   Energy Fiber Calcium  Iron Magnesium Vitamin C Vitamin B-6 Vitamin B-12  \
# 0     30   0.4       7  0.24        10       8.1       0.045         0.00
# 1     34   0.9       9  0.21        12      36.7       0.072         0.00
# 2     53   1.8      37  0.15        12      26.7       0.078         0.00
# 3     32   2.0      16  0.41        13      58.8       0.047         0.00
# 4     46   1.4       6  0.17         7       9.5       0.029         0.00
#
#   Vitamin E
# 0      0.05
# 1      0.05
# 2      0.20
# 3      0.29
# 4      0.26

# %%
DF_final.shape
# Out:
# (39, 14)

# %%
# Calculate the rank by each columns
R_edible_per_dollar = DF_final['edible_pount_per_1_dollar'].rank(axis=0, method='average')
R_Energy            = DF_final['Energy'].rank(axis=0, method='average')
R_Fiber             = DF_final['Fiber'].rank(axis=0, method='average')
R_Ca                = DF_final['Calcium'].rank(axis=0, method='average')
R_Fe                = DF_final['Iron'].rank(axis=0, method='average')
R_Mg                = DF_final['Magnesium'].rank(axis=0, method='average')
R_VC                = DF_final['Vitamin C'].rank(axis=0, method='average')
R_VB6               = DF_final['Vitamin B-6'].rank(axis=0, method='average')
R_VB12              = DF_final['Vitamin B-12'].rank(axis=0, method='average')
R_VBE               = DF_final['Vitamin E'].rank(axis=0, method='average')

# Check for Vitamin E ranking
R_VBE[0:5]
# Out:
# 0    10.5
# 1    10.5
# 2    21.0
# 3    24.0
# 4    22.0
# Name: Vitamin E, dtype: float64

# %% [markdown]
# #### Step 4: Creat a dataframe that reflects the Best Combination based on the sum of ranking across nutrients

# %%
my_dict = {'Edible_per_dollar rank' : R_edible_per_dollar,
     'Energy rank' : R_Energy,
     'Fiber rank': R_Fiber,
     'Ca rank':R_Ca,
     'Fe rank': R_Fe,
     'Mg rank': R_Mg ,
     'Vitamin C rank': R_VC,
     'Vitamin B-6 rank': R_VB6,
     'Vitamin B-12 rank': R_VB12,
     'Vitamin E': R_VBE,
     'term' : DF_final['term']}


DF_Rank = pd.DataFrame(my_dict)
DF_Rank['Best_Combination'] = DF_Rank.sum(axis=1)  # pd.df.sum(axis=1) : This will sum a row across the columns
DF_Rank.head(10)
# Out:
#    Ca rank  Edible_per_dollar rank  Energy rank  Fe rank  Fiber rank  Mg rank  \
# 0     36.0                    39.0         12.0     13.0         1.0      4.0
# 1     38.5                    35.0         17.0      7.5         7.0     12.0
# 2     25.0                    20.0         32.0      2.0        20.0     12.0
# 3     13.5                    14.0         14.5     26.5        21.5     17.0
# 4     32.5                    17.0         25.0      4.5        10.5     35.0
# 5     22.5                     1.0         30.5     32.0        39.0     22.0
# 6      1.5                     8.0         37.0     20.0        37.0     12.0
# 7      6.5                    33.0         28.5     19.0        10.5     12.0
# 8      6.5                    10.0         26.0     24.0        21.5      4.0
# 9     32.5                    24.0         18.0      4.5         6.0      4.0
#
#    Vitamin B-12 rank  Vitamin B-6 rank  Vitamin C rank  Vitamin E  \
# 0               20.0              10.0            34.0       10.5
# 1               20.0              21.0            20.0       10.5
# 2               20.0              23.0            13.0       21.0
# 3               20.0              11.0            27.0       24.0
# 4               20.0               3.5            38.0       22.0
# 5               20.0              18.5            12.0       31.0
# 6               20.0              22.0             3.0       28.0
# 7               20.0              27.0            23.0        4.0
# 8               20.0              17.0             1.5       33.0
# 9               20.0              24.0             6.5        4.0
#
#             term  Best_Combination
# 0    watermelon              179.5
# 1    cantaloupe              188.5
# 2    tangerines              188.0
# 3  strawberries              189.0
# 4         plums              208.0
# 5   raspberries              228.5
# 6   pomegranate              188.5
# 7     pineapple              183.5
# 8      apricots              163.5
# 9      honeydew              143.5

# %% [markdown]
# #### Step 5: Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
# Sortting 
DF_Rank = DF_Rank.sort_values(by='Best_Combination', ascending=False) # sort the dataframe by "column name"

# %%
# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(10, 15))

# Plotting
sns.set_color_codes("pastel")
sns.barplot(x='Best_Combination', y='term', data= DF_Rank, color="b", ci=None)

plt.xlabel("Best Combination (ranking socore)", fontsize=15)
plt.ylabel("Food", fontsize=15)
plt.yticks(fontsize=15)

plt.show()

# %% [markdown]
# #### Step 6: Results

# %% [markdown]
# In addition to the best value (price and yield) and energy (providing the energy source),I also consider the following nutrtients that play importnat role in metabolism.
#
# 1. Fe is the important element for Hemoglobin.
#
# 2. Fiber is associated with reduced diabetes risk.
#
# 3. Vitamin C Vitamin C is an essential nutrient involved in the repair of tissue and the enzymatic production of certain neurotransmitters.
#
# 4. Vitamin B6 servess as a coenzyme in some 100 enzyme reactions in amino acid, glucose, and lipid metabolism.

# %% [markdown]
# I rank the best value and each nutrition by food. Each food has a sum of ranking scores, determning the best combination of price, yield, and nutrition.
# The result shows that __banana__ and __brussel sprouts__ are the best food that provide best value, and the most amount of targeted nutrition.
